# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
data = pd.read_csv('Salary_dataset.csv')

# %%
data
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
x = data.drop('Salary' , axis=1)
y = data['Salary']

# %%
x
# Out:
#     Unnamed: 0  YearsExperience
# 0            0              1.2
# 1            1              1.4
# 2            2              1.6
# 3            3              2.1
# 4            4              2.3
# 5            5              3.0
# 6            6              3.1
# 7            7              3.3
# 8            8              3.3
# 9            9              3.8
# 10          10              4.0
# 11          11              4.1
# 12          12              4.1
# 13          13              4.2
# 14          14              4.6
# 15          15              5.0
# 16          16              5.2
# 17          17              5.4
# 18          18              6.0
# 19          19              6.1
# 20          20              6.9
# 21          21              7.2
# 22          22              8.0
# 23          23              8.3
# 24          24              8.8
# 25          25              9.1
# 26          26              9.6
# 27          27              9.7
# ...

# %%
y
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
from sklearn.model_selection import train_test_split 

X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#     Unnamed: 0  YearsExperience
# 4            4              2.3
# 16          16              5.2
# 5            5              3.0
# 13          13              4.2
# 11          11              4.1
# 22          22              8.0
# 1            1              1.4
# 2            2              1.6
# 25          25              9.1
# 3            3              2.1
# 21          21              7.2
# 26          26              9.6
# 18          18              6.0
# 29          29             10.6
# 20          20              6.9
# 7            7              3.3
# 10          10              4.0
# 14          14              4.6
# 19          19              6.1
# 6            6              3.1

# %%
y_train
# Out:
# 4      39892.0
# 16     66030.0
# 5      56643.0
# 13     57082.0
# 11     55795.0
# 22    101303.0
# 1      46206.0
# 2      37732.0
# 25    105583.0
# 3      43526.0
# 21     98274.0
# 26    116970.0
# 18     81364.0
# 29    121873.0
# 20     91739.0
# 7      54446.0
# 10     63219.0
# 14     61112.0
# 19     93941.0
# 6      60151.0
# Name: Salary, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier
Descision = DecisionTreeClassifier()
Descision
# Out:
# DecisionTreeClassifier()

# %%
Descision.fit(X_train , y_train)
# Out:
# DecisionTreeClassifier()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x_pred = Descision.predict(X_test)

# %%
from sklearn.metrics import accuracy_score ,classification_report

# %%
# Out:
# 0.0

# %%
print('Accuracy' , accuracy_score(y_test , x_pred) )
print('classification_report',classification_report(y_test , x_pred))
# Out:
# Accuracy 0.0
# classification_report               precision    recall  f1-score   support
#
#      39344.0       0.00      0.00      0.00       1.0
#      46206.0       0.00      0.00      0.00       0.0
#      54446.0       0.00      0.00      0.00       0.0
#      55795.0       0.00      0.00      0.00       0.0
#      56958.0       0.00      0.00      0.00       1.0
#      57190.0       0.00      0.00      0.00       1.0
#      63219.0       0.00      0.00      0.00       0.0
#      64446.0       0.00      0.00      0.00       1.0
#      66030.0       0.00      0.00      0.00       0.0
#      67939.0       0.00      0.00      0.00       1.0
#      83089.0       0.00      0.00      0.00       1.0
#     101303.0       0.00      0.00      0.00       0.0
#     105583.0       0.00      0.00      0.00       0.0
#     109432.0       0.00      0.00      0.00       1.0
#     112636.0       0.00      0.00      0.00       1.0
#     113813.0       0.00      0.00      0.00       1.0
# ...

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(Descision , filled=True)
plt.show()
